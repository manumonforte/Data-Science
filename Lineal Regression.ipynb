# %% [markdown]
# ## Lineal Regression

# %%
import numpy as np

# %%
import pandas as pd

# %%
movies = pd.read_csv("movies.csv")

# %%
movies.head()
# Out:
#                        franquicia  presupuesto  genero  \
# 0  Father of the Bride Collection          NaN  Comedy
# 1                             NaN          NaN   Drama
# 2               Friday Collection    3500000.0  Comedy
# 3                             NaN          NaN  Comedy
# 4                             NaN   12000000.0  Comedy
#
#                                       pagina_web    imdb_id lenguaje  \
# 0                                            NaN  tt0113041       en
# 1                                            NaN  tt0112749       en
# 2  http://www.newline.com/properties/friday.html  tt0113118       en
# 3                                            NaN  tt0115697       en
# 4                                            NaN  tt0116483       en
#
#    popularidad            productores                      pais fecha_estreno  \
# 0     8.387519  Sandollar Productions  United States of America    1995-02-10
# ...

# %%
movies_number = movies.select_dtypes(include =['float64']).fillna(0)

# %%
pelis_number.head()
# Out:
#    presupuesto  popularidad      ventas  duracion  puntuacion  n_votos
# 0          0.0     8.387519  76578911.0     106.0         5.7    173.0
# 1          0.0     0.894647    676525.0     106.0         6.7     13.0
# 2    3500000.0    14.569650  28215918.0      91.0         7.0    513.0
# 3          0.0     8.963037        32.0      87.0         6.0    124.0
# 4   12000000.0     9.592265  41205099.0      92.0         6.5    767.0

# %%
from sklearn.linear_model import LinearRegression

# %%
target = "ventas"

# %%
independents = movies_number.drop(target,axis=1).columns

# %%
model =LinearRegression()

# %%
model.fit(movies_number[independents],movies_number[target])
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
movies["ventas_pred"] = model.predict(movies_number[independents])

# %%
movies
# Out:
#                               franquicia  presupuesto           genero  \
# 0         Father of the Bride Collection          NaN           Comedy
# 1                                    NaN          NaN            Drama
# 2                      Friday Collection    3500000.0           Comedy
# 3                                    NaN          NaN           Comedy
# 4                                    NaN   12000000.0           Comedy
# 5                                    NaN          NaN           Comedy
# 6                                    NaN   31000000.0           Comedy
# 7                                    NaN   52000000.0            Drama
# 8        Brooklyn Cigar Store Collection    2000000.0           Comedy
# 9                                    NaN          NaN      Documentary
# 10                                   NaN   90000000.0  Science Fiction
# 11                                   NaN          NaN           Comedy
# ...
