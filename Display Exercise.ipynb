# %% [markdown]
# ## Display Exercise

# %%
import pandas as pd

# %%
df = pd.read_csv("datos-misteriosos.csv")
df
# Out:
#     dataset          x          y
# 0    clase1  55.384600  97.179500
# 1    clase1  51.538500  96.025600
# 2    clase1  46.153800  94.487200
# 3    clase1  42.820500  91.410300
# 4    clase1  40.769200  88.333300
# 5    clase1  38.717900  84.871800
# 6    clase1  35.641000  79.871800
# 7    clase1  33.076900  77.564100
# 8    clase1  28.974400  74.487200
# 9    clase1  26.153800  71.410300
# 10   clase1  23.076900  66.410300
# 11   clase1  22.307700  61.794900
# 12   clase1  22.307700  57.179500
# 13   clase1  23.333300  52.948700
# 14   clase1  25.897400  51.025600
# 15   clase1  29.487200  51.025600
# 16   clase1  32.820500  51.025600
# 17   clase1  35.384600  51.410300
# 18   clase1  40.256400  51.410300
# 19   clase1  44.102600  52.948700
# 20   clase1  46.666700  54.102600
# 21   clase1  50.000000  55.256400
# 22   clase1  53.076900  55.641000
# 23   clase1  56.666700  56.025600
# 24   clase1  59.230800  57.948700
# 25   clase1  61.282100  62.179500
# ...

# %%
import matplotlib.pyplot as plt

# %%
df[df.dataset=="clase1"].plot(kind="scatter",x = "x", y = "y")
plt.title("Mysterious data")
# Out:
# Text(0.5,1,'Mysterious data')

# %%
df[df.dataset=="clase2"].plot(kind="scatter",x = "x", y = "y")
plt.title("Mysterious data (2)")
# Out:
# Text(0.5,1,'Mysterious data (2)')
